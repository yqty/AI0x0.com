# %% [markdown]
# <a href="https://colab.research.google.com/github/yqty/AI0x0.com/blob/master/Stable_Diffusion_as_a_Service_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffuzers -qqqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 842.5/842.5 kB 15.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 37.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 23.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.0/376.0 kB 40.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 851.8/851.8 kB 61.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 69.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.5/191.5 kB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 72.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 7.7 MB/s eta 0:00:00
# ...

# %%
# !diffuzers api --help
# Out:
# usage: diffuzers <command> [<args>] api
#        [-h]
#        [--output OUTPUT]
#        [--port PORT]
#        [--host HOST]
#        [--device DEVICE]
#        [--workers WORKERS]
#        [--ssl_certfile SSL_CERTFILE]
#        [--ssl_keyfile SSL_KEYFILE]
#
# ✨ Run
# diffuzers
# api
#
# optional arguments:
#   -h, --help
#     show this
#     help
#     message and
#     exit
#   --output OUTPUT
#     Output path
#     is
#     optional,
#     but if
#     provided,
#     all
#     generations
#     will automa
#     tically be
#     saved to
#     this path.
#   --port PORT
#     Port to run
#     the app on
#   --host HOST
#     Host to run
#     the app on
#   --device DEVICE
#     Device to
#     use, e.g.
#     cpu, cuda,
#     cuda:0, mps
#     (for m1
#     mac) etc.
#   --workers WORKERS
#     Number of
#     workers to
#     use
#   --ssl_certfile SSL_CERTFILE
#     the path to
#     your ssl
#     cert
#   --ssl_keyfile SSL_KEYFILE
#     the path to
#     your ssl
# ...

# %%
#Environment Variable

# %%
# %env X2IMG_MODEL=stabilityai/stable-diffusion-2-1
# Out:
# env: X2IMG_MODEL=stabilityai/stable-diffusion-2-1

# %%
# %env DEVICE=cuda
# Out:
# env: DEVICE=cuda

# %%
# !diffuzers api --port 10000  & npx localtunnel --port 10000
# Out:
# npx: installed 22 in 2.09s
# your url is: https://five-pots-deny-35-239-73-33.loca.lt
# 2023-04-17 14:49:42.099393: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 14:49:43.182023: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:     Started server process [1026]
# 2023-04-17 14:49:46.418 INFO    uvicorn.error: Started server process [1026]
# INFO:     Waiting for application startup.
# 2023-04-17 14:49:46.419 INFO    uvicorn.error: Waiting for application startup.
# > INFO    @@@@@ Starting Diffuzes API @@@@@
# > INFO    Text2Image Model: stabilityai/stable-diffusion-2-1
# > INFO    Text2Image Pipeline: Vanilla
# > INFO    Inpainting Model: None
# > INFO    Device: cuda
# ...
